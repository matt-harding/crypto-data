# %%
import pandas as pd

# %%
df = pd.read_excel('Provider_Market_Data.xlsx')

# %%
df
# Out:
#     data_provider symbol         name    market_cap  circulating_supply  \
# 0       CoinGecko   BUSD  Binance USD  2.243154e+10        2.240154e+10
# 1   CoinMarketCap   BUSD  Binance USD  2.240041e+10        2.240154e+10
# 2     CoinMetrics   BUSD  Binance USD  2.247925e+10        2.248554e+10
# 3   CryptoCompare   BUSD  Binance USD  2.241048e+10        2.240154e+10
# 4       OnChainFX   BUSD  Binance USD  2.248554e+10        2.248554e+10
# ..            ...    ...          ...           ...                 ...
# 60      CoinGecko   USDC     USD Coin  4.429428e+10        4.423186e+10
# 61  CoinMarketCap   USDC     USD Coin  4.423448e+10        4.423186e+10
# 62    CoinMetrics   USDC     USD Coin  4.071894e+10        4.072496e+10
# 63  CryptoCompare   USDC     USD Coin  4.422744e+10        4.423186e+10
# 64      OnChainFX   USDC     USD Coin  4.405020e+10        4.405020e+10
#
#     total_supply  twentyfourhour_volume     price              last_updated
# ...

# %%
coins = df.name.unique()
coins
# Out:
# array(['Binance USD', 'Celo Dollar', 'Dai', 'DIGG', 'DigitalBits',
#        'Dynamic Set Dollar', 'Empty Set Dollar', 'Fei USD',
#        'Float Protocol', 'FRAX', 'Frax Share', 'Gemini Dollar',
#        'Neutrino Dollar', 'Pax Dollar', 'Sperax', 'Stasis Euro',
#        'Steem Dollars', 'Synthetix USD', 'TerraUSD', 'Tether', 'TrueUSD',
#        'USD Coin'], dtype=object)

# %%
DataFrameDict = {elem : pd.DataFrame() for elem in coins}

for key in DataFrameDict.keys():
    DataFrameDict[key] = df[:][df.name == key]

# %%
for key in ['Tether', 'Binance USD', 'Dai', 'USD Coin', 'Pax Dollar']:
    ax1 = DataFrameDict[key].plot.scatter(x='data_provider', y='price', title=key )
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1070: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1070: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1070: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1070: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# ...

# %%
for key in ['Tether', 'Binance USD', 'Dai', 'USD Coin', 'Pax Dollar']:
    ax1 = DataFrameDict[key].plot.scatter(x='data_provider', y='circulating_supply', title=key )
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1070: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1070: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1070: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1070: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# ...

# %%
for key in ['Tether', 'Binance USD', 'Dai', 'USD Coin', 'Pax Dollar']:
    ax1 = DataFrameDict[key].plot.scatter(x='data_provider', y='market_cap', title=key )
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1070: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1070: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1070: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1070: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# ...
